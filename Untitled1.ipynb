# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pprint
import pandas as pd
import matplotlib.pyplot as plt

# %%
client_id = '7fd7433f4e0e48759630aa4102c16bd7'
client_secret = '4160e392318b48438856ba35c03c0076'

# %%
client_credentials_manager = spotipy.oauth2.SpotifyClientCredentials(client_id, client_secret)
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
df = pd.read_csv('regional-jp-daily-2024-02-07.csv')
df.head()
# Out:
#    rank                                   uri      artist_names  \
# 0     1  spotify:track:0kdqcbwei4MDWFEX5f33yG       Creepy Nuts
# 1     2  spotify:track:2cxcqKwQtfKq7giphxjzOu             tuki.
# 2     3  spotify:track:1hAloWiinXLPQUJxrJReb1           YOASOBI
# 3     4  spotify:track:7sditHCsoFw3nHnjFv1BHV  Mrs. GREEN APPLE
# 4     5  spotify:track:0teqQ0PYqVDyyXJuPOyMhu  Mrs. GREEN APPLE
#
#              track_name                  source  peak_rank  previous_rank  \
# 0  Bling-Bang-Bang-Born  Sony Music Labels Inc.          1              1
# 1                   晩餐歌                  月面着陸計画          2              2
# 2                  アイドル                 YOASOBI          1              4
# 3               ナハトムジーク     Universal Music LLC          3              3
# 4                 ケセラセラ     Universal Music LLC          2              5
#
#    days_on_chart  streams
# 0             31   577352
# 1            132   327602
# 2            303   267836
# ...

# %%
plt.scatter(df['rank'], df['days_on_chart'])

# %%
plt.scatter(df['rank'], df['streams'])
